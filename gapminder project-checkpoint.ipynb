# %%
import pandas as pd
file_path = 'C:/Users/ELIZABETH AKINLEYE/Downloads/gapminder.tsv'

# %%
data = pd.read_csv("C:/Users/ELIZABETH AKINLEYE/Downloads/gapminder.tsv", sep="\t")
print(data)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 3307     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
print(data.head())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
print(data.dtypes)
# Out:
# country          str
# continent        str
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
country_data = data['country']

# %%
print(country_data.head())
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: str

# %%
print(country_data.tail())
# Out:
# 3307    Zimbabwe
# 3308    Zimbabwe
# 3309    Zimbabwe
# 3310    Zimbabwe
# 3311    Zimbabwe
# Name: country, dtype: str

# %%
subset = data[['country', 'continent', 'year']]

# %%
print (subset.head())
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
print(subset.tail())
# Out:
#        country continent  year
# 3307  Zimbabwe    Africa  1987
# 3308  Zimbabwe    Africa  1992
# 3309  Zimbabwe    Africa  1997
# 3310  Zimbabwe    Africa  2002
# 3311  Zimbabwe    Africa  2007

# %%
data.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
print(data.loc[99])
# Out:
# country        Australia
# continent            NaN
# year                1977
# lifeExp            73.49
# pop             14074100
# gdpPercap    18334.19751
# Name: 99, dtype: object

# %%
print(data.iloc[[0,99,999],[0,3,5]])
# Out:
#          country  lifeExp     gdpPercap
# 0    Afghanistan   28.801    779.445314
# 99     Australia   73.490  18334.197510
# 999      Finland   69.370  10042.219300

# %%
print(data.head(n=20))
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %%
print(data.groupby('year')['lifeExp'].mean())
# Out:
# year
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
multi_group_var= data.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()

# %%
multi_group_var
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1950 Africa     41.361500   1422.081643
#      Americas   57.976800   5331.664417
#      Asia       53.675000   1363.645814
#      Europe     65.755916   6804.996873
#      FSU        59.950000   3638.203164
# ...                   ...           ...
# 2007 Americas   73.426400   9965.129301
#      Asia       70.432146  14991.333285
#      Europe     77.299059  24174.152973
#      FSU        69.166333  12360.431827
#      Oceania    70.849333  10377.494935
#
# [285 rows x 2 columns]

# %%
print(data.groupby('continent')['country'].nunique())
# Out:
# continent
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: country, dtype: int64

# %%
global_yearly_expectancy= data.groupby('year')['lifeExp'].mean()

# %%
global_yearly_expectancy
# Out:
# year
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283438
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...
